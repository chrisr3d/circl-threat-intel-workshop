# %% [markdown]
# # PassiveSSH
#
# ## Documentation
#
# - Docs: https://d4-project.github.io/passive-ssh/
#
# ## Exercises

# %% [markdown]
# #### PassiveSSH bootstrap

# %%
import getpass
import requests
import json

PASSIVE_SSH_USER = getpass.getpass("Enter your PassiveSSH User:")
PASSIVE_SSH_KEY = getpass.getpass("Enter your PassiveSSH API Password:")

pssh = requests.Session()
pssh.auth = (PASSIVE_SSH_USER, PASSIVE_SSH_KEY)

# %% [markdown]
# #### 1.0. Get all SSH banners (slow)
# - *Hint*: related API endpoint: `https://pssh.circl.lu/banners`

# %%
data = pssh.get(f'https://pssh.circl.lu/banners').json()
print(f"Total banners: {len(data['banners'])}")
bottom10_banners = list(data['banners'].keys())[-10:]
print("Showing bottom last 10 banners:")
for banner in bottom10_banners:
    print(f"- {banner}")

# %% [markdown]
# #### 1.1. Get hosts using a given banner
# - *Hint*: related API endpoint: `https://www.pssh.circl.lu/banner/hosts/[banner]`

# %%
banner = 'SSH-2.0-GIfQrwMLPdNQT99'
data = pssh.get(f"https://pssh.circl.lu/banner/hosts/{banner}").json()
print(json.dumps(data, indent=4))

# %% [markdown]
# #### 1.2. Get SSH info of a host
# - *Hint*: related API endpoint: `https://pssh.circl.lu/host/ssh/[host]`

# %%
host = '216.75.130.11'
data = pssh.get(f"https://pssh.circl.lu/host/ssh/{host}").json()
print(json.dumps(data, indent=4))

# %% [markdown]
# #### 1.3. Get the history of a host
# - *Hint*: related API endpoint: `https://pssh.circl.lu/host/history/[host]`

# %%
host = '216.75.130.11'
data = pssh.get(f"https://pssh.circl.lu/host/history/{host}").json()
print(json.dumps(data, indent=4))

# %% [markdown]
# #### 1.3. Get the hosts behind a fingerprint
# - *Hint*: related API endpoint: `https://pssh.circl.lu/fingerprint/all/[fingerprint]`

# %%
fingerprint = 'f2:90:ec:c6:49:fd:fc:98:70:d8:60:db:47:97:09:6a'
data = pssh.get(f"https://pssh.circl.lu/fingerprint/all/{fingerprint}").json()
print(json.dumps(data, indent=4))
